# %% [markdown]
# <a href="https://colab.research.google.com/github/Bhartiankita369/PW_assignment/blob/main/numpy%26pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Q1. Load the given retail sales dataset into a Pandas DataFrame and display the first 5 rows along with the
# dataset information to understand its structure.

# %%
import pandas as pd
df=pd.read_csv("retail_dataset .csv")
print(df.head())
# Out:
#   Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0           T001        C015            Books       7.0   167.0  02-02-2023
# 1           T002        C004             Toys       4.0   374.0  17-02-2023
# 2           T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3           T004        C047        Groceries       5.0   304.0  11-02-2024
# 4           T005        C022            Books       7.0   282.0  27-07-2024
#
#   Region
# 0  North
# 1  South
# 2  South
# 3  South
# 4   West

# %% [markdown]
# Q2. Inspect the dataset and identify missing values in each column. Display the total number of missing
# values present in the dataset.

# %%
# Check missing values in each column
print("Missing values in each column:")
print(df.isnull().sum())

# Total missing values in dataset
print("\nTotal missing values:")
print(df.isnull().sum().sum())
# Out:
# Missing values in each column:
# Transaction ID      0
# Customer ID         0
# Product Category    3
# Quantity            2
# Price               5
# Date                0
# Region              2
# dtype: int64
#
# Total missing values:
# 12

# %% [markdown]
# Q3. Replace missing values in the Quantity and Price columns with their respective mean values using
# Pandas.

# %%
# Replace missing values with mean
df["Quantity"].fillna(df["Quantity"].mean())
df["Price"].fillna(df["Price"].mean())

print(df)
# Out:
#    Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0            T001        C015            Books       7.0   167.0  02-02-2023
# 1            T002        C004             Toys       4.0   374.0  17-02-2023
# 2            T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3            T004        C047        Groceries       5.0   304.0  11-02-2024
# 4            T005        C022            Books       7.0   282.0  27-07-2024
# ..            ...         ...              ...       ...     ...         ...
# 95           T096        C036        Furniture      10.0  2901.0  08-08-2023
# 96           T097        C021         Clothing       9.0  1077.0  19-07-2024
# 97           T098        C015         Clothing       7.0   643.0  13-08-2023
# 98           T099        C005        Groceries       9.0   429.0  20-01-2024
# 99           T100        C010        Furniture       8.0  1183.0  07-02-2024
#
#    Region
# 0   North
# 1   South
# 2   South
# 3   South
# 4    West
# ..    ...
# 95  North
# 96  North
# 97  North
# 98  South
# 99  North
#
# [100 rows x 7 columns]

# %% [markdown]
# Q4. Remove all rows where the Product Category or Region column contains missing values.

# %%
df = df.dropna(subset=["Product Category", "Region"])
print(df)
# Out:
#    Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0            T001        C015            Books       7.0   167.0  02-02-2023
# 1            T002        C004             Toys       4.0   374.0  17-02-2023
# 2            T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3            T004        C047        Groceries       5.0   304.0  11-02-2024
# 4            T005        C022            Books       7.0   282.0  27-07-2024
# ..            ...         ...              ...       ...     ...         ...
# 95           T096        C036        Furniture      10.0  2901.0  08-08-2023
# 96           T097        C021         Clothing       9.0  1077.0  19-07-2024
# 97           T098        C015         Clothing       7.0   643.0  13-08-2023
# 98           T099        C005        Groceries       9.0   429.0  20-01-2024
# 99           T100        C010        Furniture       8.0  1183.0  07-02-2024
#
#    Region
# 0   North
# 1   South
# 2   South
# 3   South
# 4    West
# ..    ...
# 95  North
# 96  North
# 97  North
# 98  South
# 99  North
#
# [95 rows x 7 columns]

# %% [markdown]
# Q5. Create a new column called Revenue using NumPy, where:
#
# Revenue = Quantity × Price
#
# Display the updated dataset with the new column.

# %%
import numpy as np
df["Revenue"] = np.multiply(df["Quantity"], df["Price"])

print(df)
# Out:
#    Transaction ID Customer ID Product Category  Quantity   Price        Date  \
# 0            T001        C015            Books       7.0   167.0  02-02-2023
# 1            T002        C004             Toys       4.0   374.0  17-02-2023
# 2            T003        C033        Furniture       8.0  1059.0  17-05-2024
# 3            T004        C047        Groceries       5.0   304.0  11-02-2024
# 4            T005        C022            Books       7.0   282.0  27-07-2024
# ..            ...         ...              ...       ...     ...         ...
# 95           T096        C036        Furniture      10.0  2901.0  08-08-2023
# 96           T097        C021         Clothing       9.0  1077.0  19-07-2024
# 97           T098        C015         Clothing       7.0   643.0  13-08-2023
# 98           T099        C005        Groceries       9.0   429.0  20-01-2024
# 99           T100        C010        Furniture       8.0  1183.0  07-02-2024
#
#    Region  Revenue
# 0   North   1169.0
# 1   South   1496.0
# 2   South   8472.0
# 3   South   1520.0
# 4    West   1974.0
# ..    ...      ...
# 95  North  29010.0
# 96  North   9693.0
# 97  North   4501.0
# 98  South   3861.0
# 99  North   9464.0
#
# [95 rows x 8 columns]

# %% [markdown]
# Q6. Using NumPy, calculate the total revenue generated from all transactions in the dataset.

# %%
import numpy as np
print(np.sum(df["Quantity"] * df['Price']))
# Out:
# 465529.66058002145

# %% [markdown]
# Q7. Group the dataset by Product Category and calculate the total revenue generated by each category.

# %%
df['revenue_by_category'] = df.groupby('Product Category')['Revenue'].sum()

print("Total revenue by product category: ")
print(revenue_by_category)
# Out:
# Total revenue by product category:
# Product Category
# Beauty          27647.000000
# Books           29597.938776
# Clothing        85006.000000
# Electronics     93204.315789
# Furniture      129664.526316
# Groceries       11978.000000
# Sports          34484.000000
# Toys            53947.879699
# Name: Revenue, dtype: float64

# %% [markdown]
# Q8. Based on the revenue calculated for each product category, identify the top 3 categories with the
# highest revenue and the bottom 3 categories with the lowest revenue.

# %%
# Top 3 categories (highest revenue)
top_3 = revenue_by_category.sort_values(ascending=False).head(3)

# Bottom 3 categories (lowest revenue)
bottom_3 = revenue_by_category.sort_values(ascending=True).head(3)

print("Top 3 Categories by Revenue:")
print(top_3)

print("\nBottom 3 Categories by Revenue:")
print(bottom_3)
# Out:
# Top 3 Categories by Revenue:
# Product Category
# Furniture      129664.526316
# Electronics     93204.315789
# Clothing        85006.000000
# Name: Revenue, dtype: float64
#
# Bottom 3 Categories by Revenue:
# Product Category
# Groceries    11978.000000
# Beauty       27647.000000
# Books        29597.938776
# Name: Revenue, dtype: float64

# %% [markdown]
# Q9. Group the dataset by Region and calculate the total revenue generated in each region. Identify the
# region with the highest revenue and the region with the lowest revenue.

# %%
region_revenue = df.groupby("Region")["Revenue"].sum()

print("Revenue by Region:")
print(region_revenue)

# Identify highest and lowest revenue regions
highest_region = region_revenue.idxmax()
lowest_region = region_revenue.idxmin()

print("\nRegion with Highest Revenue:", highest_region)
print("Region with Lowest Revenue:", lowest_region)
# Out:
# Revenue by Region:
# Region
# East     126232.044039
# North    153244.353383
# South    104855.736842
# West      81197.526316
# Name: Revenue, dtype: float64
#
# Region with Highest Revenue: North
# Region with Lowest Revenue: West

# %% [markdown]
# Q10. Extract the month from the Date column using Pandas and group the dataset by month to calculate the
# total monthly revenue. Also, calculate the mean, median, and standard deviation of the Revenue column
# using NumPy.

# %%
# Convert Date column to datetime
df["Date"] = pd.to_datetime(df["Date"],format= '%d-%m-%y')

# Extract Month
df["Month"] = df["Date"].dt.month

# Group by Month and calculate total revenue
monthly_revenue = df.groupby("Month")["Revenue"].sum()

print("Monthly Revenue:")
print(monthly_revenue)

# NumPy statistics on Revenue
mean_rev = np.mean(df["Revenue"])
median_rev = np.median(df["Revenue"])
std_rev = np.std(df["Revenue"])

print("\nRevenue Statistics:")
print("Mean:", mean_rev)
print("Median:", median_rev)
print("Standard Deviation:", std_rev)
# Out:
# Monthly Revenue:
# Month
# 1     43994.000000
# 2     33028.000000
# 3     10557.000000
# 4     57298.526316
# 5     27915.000000
# 6     28190.000000
# 7     47851.292159
# 8     76958.000000
# 9     30719.105263
# 10    38017.000000
# 11    27662.736842
# 12    43339.000000
# Name: Revenue, dtype: float64
#
# Revenue Statistics:
# Mean: 4900.312216631804
# Median: 3282.1052631578946
# Standard Deviation: 4721.171795257337
